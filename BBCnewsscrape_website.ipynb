# %% [markdown]
# Task: Web Scraping and Data Visualization from BBC News
#
# Objective: Scrape data from the BBC News website, store the data in a CSV file, and create visualizations based on the collected data.
#
# Instructions:
#
# Website to Scrape:
# Visit the BBC News website at https://www.bbc.com/news.
#
#
# Data to Collect:
# 1 Headlines of news articles,
# 2 Author names (if available),
# 3 Summary or description of the articles,
# 4 URLs of the articles.
#
# Data Storage:
# Store the scraped data in a CSV file with the following columns: headline, publication_date, author, summary, url.
#
# Documentation:
# Document the steps taken in the scraping process and any challenges faced.
# Include comments in the code for clarity.
#
# Submission:
# Submit the CSV file and visualizations, along with the source code and documentation.

# %%
import requests

data=requests.get("https://www.bbc.com/news")
page_contents=data.text

# %%
print(data.status_code)
# Out:
# 200

# %% [markdown]
# # Fetch Headlines of news articles

# %%
import requests
from bs4 import BeautifulSoup

url='https://www.bbc.com/news'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
#print(soup)
def get_headlines_newsarticles(soup):
    headlines = soup.find('body').find_all('h2')
    headlines_news=[]
    for x in headlines:
        headlines_news.append(x.text.strip())
    return headlines_news

# %%
get_headlines_newsarticles(soup)
# Out:
# ['Bowen: Year of killing and broken assumptions has taken Middle East to edge of deeper, wider war',
#  'Israeli air strikes hit Gaza and Beirut as 7 October attacks remembered',
#  'Maldives president in Delhi to seek aid and reboot ties',
#  'Orla Gartland: US tour will cost me thousands',
#  'New hurricane threatens Florida as it reels from devastation',
#  'Israeli air strikes hit Gaza and Beirut as 7 October attacks remembered',
#  "Blast kills two Chinese near Pakistan's Karachi airport",
#  'Russian opposition activist killed fighting for Ukraine',
#  'Climbers rescued after three days missing in Himalayas',
#  'Maldives president in Delhi to seek aid and reboot ties',
#  'Antisemitic incidents in US surge to record high - report',
#  'Policewoman killed and 10 injured in shooting in Israel',
#  'New Zealand loses first naval ship to sea since WW2',
#  "Judi Dench speaks of grief after Maggie Smith's death",
#  'Tool promised to help non-verbal people - but did it manipulate them instead?',
#  'Conflict in Middle East',
#  "Shattered community at Kibbutz Be'eri is struggling to heal",
#  'Gaza in maps: How life in the territory has been upended',
#  'Journalists from across the BBC reflect on the year-long war',
#  'New accounts reveal how one military base was overrun',
#  'More to explore',
#  'Oasis on the Adriatic where Ukrainians and Russians have gone to escape war',
#  'Trump and Harris are deadlocked -  could an October surprise change the game?',
#  'Can selling off homes for $1 solve urban blight?',
#  'Ghost guns and transgender care: Major cases before US Supreme Court',
#  'Immunotherapy saved my life. Can research improve the odds for others?',
#  'Trump and Harris are deadlocked -  could an October surprise change the game?',
#  "Could the deaths of 20 school children help make Thailand's roads safer?",
#  'The Polish artist who painted Hindu gods in Indian palaces',
#  'Can selling off homes for $1 solve urban blight?',
#  'Most watched',
#  'Powerful explosion rocks Beirut overnight',
#  "'Bags of sweets amid rubble of flattened Beirut building'",
#  'Moment huge explosion shakes Beirut',
#  'Watch: BBC reporter in the midst of rocket fire into Israel',
#  'Months on, Trump shooting witness still stunned by security lapse',
#  'Also in news',
#  'Woman gets reply about job application - 48 years on',
#  'Mum of woman murdered on Tinder date completes Everest trek',
#  "Married at First Sight counselling 'nothing like the real thing'",
#  'Political row erupts over Hurricane Helene disaster relief',
#  'Notorious Menendez brothers murder case to be reviewed',
#  'Mum of woman murdered on Tinder date completes Everest trek',
#  'UK-Israeli hostage has been forgotten, says mum',
#  'My mission is to take Tamil music global, says Sid Sriram',
#  "Married at First Sight counselling 'nothing like the real thing'",
#  'Most read',
#  "Blast kills two Chinese near Pakistan's Karachi airport",
#  'Bowen: Year of killing and broken assumptions has taken Middle East to edge of deeper, wider war',
#  'Climbers rescued after three days on mountain',
#  'New Zealand loses first naval ship to sea since WW2',
#  'Oasis on the Adriatic where Ukrainians and Russians have gone to escape war',
#  "Judi Dench speaks of grief after Maggie Smith's death",
#  'US election polls: Who is ahead - Harris or Trump?',
#  'Russian opposition activist killed fighting for Ukraine',
#  'Maldives president in Delhi to seek aid and reboot ties',
#  'New hurricane threatens Florida as it reels from devastation',
#  'Sport',
#  'Pakistan win toss and bat against England in first Test',
#  'What now for Ten Hag? Five things for Man Utd bosses to consider',
#  'Lewandowski hat-trick regains Barca advantage at top of La Liga',
#  'Unconvincing India beat rivals Pakistan for first win',
#  'Vikings hold on to deny Rodgers & Jets comeback London win',
#  'What now for Ten Hag? Five things for Man Utd bosses to consider',
#  'England cut loose in ruthless win over New Zealand',
#  "Postecoglou unhappy with 'worst' Tottenham defeat",
#  'Lewandowski hat-trick regains Barca advantage at top of La Liga',
#  'Follow BBC on:']

# %% [markdown]
# # Fetch Article URL

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.bbc.com/news'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

def get_article_url(soup):
    article_urls = set()  
    base_url = 'https://www.bbc.com'

    
    for tag in soup.find_all("a", href=True):
        href = tag['href']

        # Check if the link is an internal link (starts with "/")
        if href.startswith("/news"):  # Filter for news articles only
            full_url = base_url + href
            article_urls.add(full_url)
        
    return list(article_urls)

article_links = get_article_url(soup)
for link in article_links:
    print(link)
# Out:
# https://www.bbc.com/news/bbcindepth
# https://www.bbc.com/news/war-in-ukraine
# https://www.bbc.com/news/world/europe
# https://www.bbc.com/news/articles/c8xe17pegrno
# https://www.bbc.com/news/uk
# https://www.bbc.com/news/articles/c8dj0833g99o
# https://www.bbc.com/news/topics/cwywpe90nnyt
# https://www.bbc.com/news/articles/cg7825rk8j9o
# https://www.bbc.com/news/articles/cyvye9l43dgo
# https://www.bbc.com/news/reality_check
# https://www.bbc.com/news/articles/ce3we9n0v79o
# https://www.bbc.com/news/topics/c79wd85wg8et
# https://www.bbc.com/news/scotland
# https://www.bbc.com/news/world/australia
# https://www.bbc.com/news/articles/c5y0jm7jpx8o
# https://www.bbc.com/news/northern_ireland
# https://www.bbc.com/news/videos/c625nlxjpz7o
# https://www.bbc.com/news/articles/crl8e084r9yo
# https://www.bbc.com/news/scotland/scotland_politics
# https://www.bbc.com/news/world/africa
# https://www.bbc.com/news/world/middle_east
# https://www.bbc.com/news/articles/ced0wlqnvlno
# https://www.bbc.com/news/world/latin_america
# https://www.bbc.com/news/topics/cp7r8vgl2lgt
# https://www.bbc.com/news/articles/c4glkklvjrvo
# https://www.bbc.com/news/us-canada
# https://www.bbc.com/news
# https://www.bbc.com/news/articles/c77xdp1e56yo
# https://www.bbc.com/news/topics/c34k011x7rrt
# https://www.bbc.com/news/articles/c93y147z4pdo
# https://www.bbc.com/news/in_pictures
# https://www.bbc.com/news/videos/cpqz4qz554qo
# https://www.bbc.com/news/world/asia/china
# https://www.bbc.com/news/articles/cq5eyqjz1yjo
# https://www.bbc.com/news/england
# https://www.bbc.com/news/articles/c2ek1x3p7rjo
# https://www.bbc.com/news/articles/cvgwwqpdj74o
# https://www.bbc.com/news/videos/cwy91d1g057o
# https://www.bbc.com/news/videos/cg78v0l5gxvo
# https://www.bbc.com/news/articles/cm240jyl09go
# https://www.bbc.com/news/northern_ireland/northern_ireland_politics
# https://www.bbc.com/news/articles/c0r84p0dp1jo
# https://www.bbc.com/news/articles/cpqzyvv2g4vo
# https://www.bbc.com/news/wales
# https://www.bbc.com/news/world/asia/india
# https://www.bbc.com/news/articles/cwyv16lw1leo
# https://www.bbc.com/news/articles/c1e8g5leve0o
# https://www.bbc.com/news/articles/c153pg278npo
# https://www.bbc.com/news/wales/wales_politics
# https://www.bbc.com/news/topics/cj3ergr8209t
# https://www.bbc.com/news/articles/c781vgy3918o
# https://www.bbc.com/news/politics
# https://www.bbc.com/news/articles/c5y3qgqxpwno
# https://www.bbc.com/news/world/asia
# https://www.bbc.com/news/articles/cj4x71znwxdo
# https://www.bbc.com/news/articles/c9wkxv9d99vo
# https://www.bbc.com/news/videos/czrm4k1e7d0o
# https://www.bbc.com/news/articles/c5y923k2pwro
# https://www.bbc.com/news/articles/c30305l5jqpo
# https://www.bbc.com/news/topics/c2vdnvdg6xxt
# https://www.bbc.com/news/articles/ckg2987l8x7o
# https://www.bbc.com/news/world-middle-east-20415675
# https://www.bbc.com/news/articles/c206zn2gy37o
# https://www.bbc.com/news/articles/cz04n1kg1d4o
# https://www.bbc.com/news/articles/c8djrdzn19vo

# %% [markdown]
# # Author Name

# %%
import requests
from bs4 import BeautifulSoup
import json

# Function to fetch author name from the article URL
def fetch_author_name(article_url):
    try:
        # Fetch the webpage content
        response = requests.get(article_url)
        response.raise_for_status()  # Raise an error for bad responses

        # Parse the webpage using BeautifulSoup
        article_soup = BeautifulSoup(response.text, 'html.parser')

        # Attempt to find author name in the structured data (JSON-LD)
        script_tag = article_soup.find('script', type='application/ld+json')

        author_name = "Author not found"  # Default value if author is not found
        if script_tag:
            try:
                json_data = json.loads(script_tag.string)

                # Extract author name if available in the JSON-LD data
                if 'author' in json_data and isinstance(json_data['author'], list) and 'name' in json_data['author'][0]:
                    author_name = json_data['author'][0]['name']
            except (KeyError, json.JSONDecodeError):
                pass  # Handle cases where the JSON data does not have the required structure

        return author_name

    except requests.RequestException as e:
        return "Error", f"Error fetching article: {e}"


# Iterate over article links and fetch author names
for url in article_links:
    author_name = fetch_author_name(url)
    print(f"URL: {url}\nAuthor: {author_name}\n")
# Out:
# URL: https://www.bbc.com/news/bbcindepth
# Author: Author not found
#
# URL: https://www.bbc.com/news/war-in-ukraine
# Author: Author not found
#
# URL: https://www.bbc.com/news/world/europe
# Author: Author not found
#
# URL: https://www.bbc.com/news/uk
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c8dj0833g99o
# Author: Graeme Baker
#
# URL: https://www.bbc.com/news/topics/cwywpe90nnyt
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/cyvye9l43dgo
# Author: Robert Greenall
#
# URL: https://www.bbc.com/news/articles/ce3we9n0v79o
# Author: Lucy Manning
#
# URL: https://www.bbc.com/news/reality_check
# Author: Author not found
#
# URL: https://shop.bbc.com/
# Author: Author not found
#
# URL: https://www.bbc.com/news/topics/c79wd85wg8et
# Author: Author not found
#
# URL: https://www.bbc.com/news/scotland
# Author: Author not found
#
# URL: https://www.bbc.com/newsletters
# Author: Author not found
#
# URL: https://www.bbc.com/news/world/australia
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/cly6kx3ywq4o
# Author: Justin Dealey
#
# URL: https://www.bbc.com/news/northern_ireland
# Author: Author not found
#
# URL: https://www.bbc.com/news/world-middle-east-67053011
# Author: Author not found
#
# URL: https://www.bbc.com/news/videos/c625nlxjpz7o
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/crl8e084r9yo
# Author: Zahra Fatima and James FitzGerald
#
# URL: https://www.bbc.com/advertisingcontact
# Author: Author not found
#
# URL: https://www.bbc.com/news/scotland/scotland_politics
# Author: Author not found
#
# URL: https://www.bbc.com/sport/cricket/live/cervpppzv42t
# Author: Author not found
#
# URL: https://www.bbc.com/news/world/africa
# Author: Author not found
#
# URL: https://www.bbc.com/news/world/middle_east
# Author: Author not found
#
# URL: https://www.bbc.com/news/videos/czxd3yvkzn5o
# Author: Author not found
#
# URL: https://www.bbc.com/news/world/latin_america
# Author: Author not found
#
# URL: https://www.bbc.com/news/topics/cp7r8vgl2lgt
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c4glkklvjrvo
# Author: Yasmin Rufo
#
# URL: https://www.bbc.com/news/us-canada
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c3wp46l3gv4o
# Author: Guy Lynn, Eric Anderson and Stephen Menon
#
# URL: https://www.bbc.com/news
# Author: Author not found
#
# URL: https://www.bbc.com/news/topics/c34k011x7rrt
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c93y147z4pdo
# Author: Rachael McMenemy
#
# URL: https://www.bbc.com/news/in_pictures
# Author: Author not found
#
# URL: https://www.bbc.com/sport/football/live/cjd5j1rjzg0t
# Author: Author not found
#
# URL: https://www.bbc.com/news/world/asia/china
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c3rl1y3wp0jo
# Author: Emma Saunders
#
# URL: https://www.bbc.com/news/england
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c2ek1x3p7rjo
# Author: Anbarasan Ethirajan
#
# URL: https://www.bbc.com/news/articles/cvgwwqpdj74o
# Author: Sarika Unadkat
#
# URL: https://www.bbc.com/
# Author: Author not found
#
# URL: https://www.bbc.com/usingthebbc/cookies/how-can-i-change-my-bbc-cookie-settings/
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/cm240jyl09go
# Author: Jake Zuckerman
#
# URL: https://www.bbc.com/news/northern_ireland/northern_ireland_politics
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c0r84p0dp1jo
# Author: Caroline Davis
#
# URL: https://www.bbc.com/news/articles/cpqzyvv2g4vo
# Author: Joel Gunter
#
# URL: https://www.bbc.com/news/wales
# Author: Author not found
#
# URL: https://www.bbc.com/news/world/asia/india
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c153pg278npo
# Author: Dominic Hughes
#
# URL: https://www.bbc.com/news/articles/c1e8g5leve0o
# Author: Rowan Bridge
#
# URL: https://www.bbc.com/news/videos/c89l8v3qd7go
# Author: Author not found
#
# URL: https://www.bbc.com/news/wales/wales_politics
# Author: Author not found
#
# URL: https://www.bbc.com/usingthebbc/cookies/
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c79nrgp97x9o
# Author: James Gallagher
#
# URL: https://www.bbc.com/contact-bbc-com-help
# Author: Author not found
#
# URL: https://www.bbc.com/usingthebbc/privacy/
# Author: Author not found
#
# URL: https://www.bbc.com/news/topics/cj3ergr8209t
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c781vgy3918o
# Author: Jeremy Bowen
#
# URL: https://www.bbc.com/news/politics
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c5y3qgqxpwno
# Author: Brajesh Upadhyay and Jake Horton
#
# URL: https://www.bbc.com/news/world/asia
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c981pv02vryo
# Author: Matt Murphy
#
# URL: https://www.bbc.com/news/articles/cj4x71znwxdo
# Author: By the Visual Journalism and Data teams
#
# URL: https://www.bbc.com/weather
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c206zn2gy37o
# Author: Holly Honderich
#
# URL: https://www.bbc.com/news/videos/czrm4k1e7d0o
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c5y923k2pwro
# Author: Mark Savage
#
# URL: https://www.bbc.com/news/articles/c30305l5jqpo
# Author: Alice Cuddy
#
# URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/ckg2987l8x7o
# Author: Charlie Jones
#
# URL: https://www.bbc.com/news/world-middle-east-20415675
# Author: the Visual Journalism Team
#
# URL: https://www.bbc.com/news/live/cqxryqvz9j4t
# Author: Author not found
#
# URL: https://www.bbc.com/news/videos/cx2ke88kx0ro
# Author: Author not found
#
# URL: https://www.bbc.com/news/articles/c206z9ggp9yo
# Author: Mark Savage
#
# URL: https://www.bbc.com/news/articles/cz04n1kg1d4o
# Author: Anthony Zurcher
#
# URL: https://www.bbc.com/news/articles/cx20dr33xjeo
# Author: Gary O'Donoghue

# %% [markdown]
# # Author name for Single URL

# %%
import json
def fetch_author_names(article_url):
    
    try:
        response = requests.get(article_url)
        response.raise_for_status()  # Raise an error for bad responses
        article_soup = BeautifulSoup(response.text, 'html.parser')
        

        script_tag = article_soup.find('script', type='application/ld+json')

        # Load the JSON content from the script tag
        json_data = json.loads(script_tag.string)

        # Extract the author name
        author_name = json_data['author'][0]['name']

        # Print the author name
        print(f"Author: {author_name}")

          
        
        #author_tag=article_soup.find('div', {'data-testid': 'byline-new-contributors'})
        #print(author_tag)
        description_tag = article_soup.find('meta', property='og:description')  
        
                
        if description_tag:
            return description_tag['content'].strip()  # Get the content of the meta tag
        else:
            return "Description not found"

    except requests.RequestException as e:
        return f"Error fetching article: {e}"

for url in article_links:
    description = fetch_author_names(url)
    print(f"URL: {url}\nDescription: {description}\n")
#article_url="https://www.bbc.com/news/articles/c8dj0833g99o"
#fetch_article_description(article_url)
# Out:
# Author: Graeme Baker
# 'Alejandro Arcos is the second politician to be killed in a week in the city of Chilpachingo.'

# %% [markdown]
# # Summary or description of the articles

# %%
import requests
from bs4 import BeautifulSoup

def fetch_article_description(article_url):
    try:
        response = requests.get(article_url)
        response.raise_for_status()  # Raise an error for bad responses
        article_soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the description or summary
        # Adjust the selector based on the actual HTML structure of the article
        description_tag = article_soup.find('meta', property='og:description')  # Example for Open Graph description
        
        if description_tag:
            return description_tag['content'].strip()  # Get the content of the meta tag
        else:
            return "Description not found"

    except requests.RequestException as e:
        return f"Error fetching article: {e}"

# Example of usage
# Assuming you already have a BeautifulSoup object for a BBC news page
# soup = BeautifulSoup(your_html_content, 'html.parser')
# article_urls = get_article_url(soup)

for url in article_links:
    description = fetch_article_description(url)
    print(f"URL: {url}\nDescription: {description}\n")
# Out:
# URL: https://www.bbc.com/news/bbcindepth
# Description: Thought-provoking analysis from our top journalists that informs, feeds your curiosity, and helps you make sense of a complex world.
#
# URL: https://www.bbc.com/news/war-in-ukraine
# Description: Follow the latest news about the Russia Ukraine war. Find reports from the ground, verified videos, maps and expert analysis by BBC correspondents across the world.
#
# URL: https://www.bbc.com/news/world/europe
# Description: Get all the latest news, live updates and content about Europe from across the BBC.
#
# URL: https://www.bbc.com/news/uk
# Description: Get all the latest news, live updates and content about the UK from across the BBC.
#
# URL: https://www.bbc.com/news/articles/c8dj0833g99o
# Description: Alejandro Arcos is the second politician to be killed in a week in the city of Chilpachingo.
#
# URL: https://www.bbc.com/news/topics/cwywpe90nnyt
# Description: Description not found
#
# URL: https://www.bbc.com/news/articles/cyvye9l43dgo
# Description: Immigrants descended in large numbers on Montenegro, which has managed the influx despite its small size.
#
# URL: https://www.bbc.com/news/articles/ce3we9n0v79o
# Description: A mother calls for the UK to do more to rescue her daughter, taken as a hostage during the 7 October attacks.
#
# URL: https://www.bbc.com/news/reality_check
# Description: Get all the latest news, live updates and content about BBC Verify from across the BBC.
#
# URL: https://shop.bbc.com/
# Description: The Best of British TV and Culture. Celebrate your favourite shows: Doctor Who, Top Gear, Sherlock, and many more! Shop bestselling DVDs, Blu-rays and merchandise direct from the BBC Shop.
#
# URL: https://www.bbc.com/news/topics/c79wd85wg8et
# Description: Description not found
#
# URL: https://www.bbc.com/news/scotland
# Description: Get all the latest news, live updates and content about the Scotland from across the BBC.
#
# URL: https://www.bbc.com/newsletters
# Description: BBC Newsletters sign-up page
#
# URL: https://www.bbc.com/news/world/australia
# Description: Get all the latest news, live updates and content about Australia from across the BBC.
#
# URL: https://www.bbc.com/news/articles/cly6kx3ywq4o
# Description: Carole Ann Ford is the last surviving original cast member of the first Doctor Who series.
#
# URL: https://www.bbc.com/news/northern_ireland
# Description: Get all the latest news, live updates and content about Northern Ireland from across the BBC.
#
# URL: https://www.bbc.com/news/world-middle-east-67053011
# Description: A total of 97 hostages taken captive after the 7 October attacks, still remain unaccounted for.
#
# URL: https://www.bbc.com/news/videos/c625nlxjpz7o
# Description: On the one-year anniversary of the 7 October Hamas attacks in Israel, survivor Hadas Kalderon speaks to the BBC.
#
# URL: https://www.bbc.com/news/articles/crl8e084r9yo
# Description: Evacuations are planned just days after the US's deadliest mainland storm since Katrina in 2005.
#
# URL: https://www.bbc.com/advertisingcontact
# Description: Visit BBC for trusted reporting on the latest world and U.S. news, sports, business, climate, innovation, culture and much more.
#
# URL: https://www.bbc.com/news/scotland/scotland_politics
# Description: Get all the latest news, live updates and content about Scotland Politics from across the BBC.
#
# URL: https://www.bbc.com/sport/cricket/live/cervpppzv42t
# Description: Pakistan host England in the first Test at Multan Cricket Stadium – follow text & score updates plus radio commentary.
#
# URL: https://www.bbc.com/news/world/africa
# Description: Get all the latest news, live updates and content about Africa from across the BBC.
#
# URL: https://www.bbc.com/news/world/middle_east
# Description: Get all the latest news, live updates and content about the Middle East from across the BBC.
#
# URL: https://www.bbc.com/news/videos/czxd3yvkzn5o
# Description: The BBC's Hugo Bachega reports from the scene of an overnight Israeli strike in Lebanon.
#
# URL: https://www.bbc.com/news/world/latin_america
# Description: Get all the latest news, live updates and content about Latin America from across the BBC.
#
# URL: https://www.bbc.com/news/topics/cp7r8vgl2lgt
# Description: Description not found
#
# URL: https://www.bbc.com/news/articles/c4glkklvjrvo
# Description: To what extent is the advice given on MAFS similar to the therapy that happens in a real counselling room?
#
# URL: https://www.bbc.com/news/us-canada
# Description: Get all the latest news, live updates and content about the US & Canada from across the BBC.
#
# URL: https://www.bbc.com/news/articles/c3wp46l3gv4o
# Description: A BBC investigation has exposed widespread deception in food hygiene ratings across east London.
#
# URL: https://www.bbc.com/news
# Description: Visit BBC News for up-to-the-minute news, breaking news, video, audio and feature stories. BBC News provides trusted World and UK news as well as local and regional perspectives. Also entertainment, business, science, technology and health news.
#
# URL: https://www.bbc.com/news/topics/c34k011x7rrt
# Description: Description not found
#
# URL: https://www.bbc.com/news/articles/c93y147z4pdo
# Description: Fay Manners says she is "mentally destroyed" after a battle for survival 20,000ft up a mountain.
#
# URL: https://www.bbc.com/news/in_pictures
# Description: Get all the latest news, live updates and content about In Pictures from across the BBC.
#
# URL: https://www.bbc.com/sport/football/live/cjd5j1rjzg0t
# Description: Premier League reaction and Phil McNulty Q&A as Brighton come from 2-0 down to beat Spurs, while Man Utd draw with Villa and Chelsea held by Forest.
#
# URL: https://www.bbc.com/news/world/asia/china
# Description: Get all the latest news, live updates and content about China from across the BBC.
#
# URL: https://www.bbc.com/news/articles/c3rl1y3wp0jo
# Description: The veteran star says her younger brother was the "closest thing to me for so long".
#
# URL: https://www.bbc.com/news/england
# Description: Get all the latest news, live updates and content about England from across the BBC.
#
# URL: https://www.bbc.com/news/articles/c2ek1x3p7rjo
# Description: Mohamed Muizzu is expected to seek a bailout worth hundreds of millions of dollars during his India visit.
#
# URL: https://www.bbc.com/news/articles/cvgwwqpdj74o
# Description: The Indian-born, American-raised artist is going to perform his biggest solo UK show.
#
# URL: https://www.bbc.com/
# Description: Visit BBC for trusted reporting on the latest world and US news, sports, business, climate, innovation, culture and much more.
#
# URL: https://www.bbc.com/usingthebbc/cookies/how-can-i-change-my-bbc-cookie-settings/
# Description:
#
# URL: https://www.bbc.com/news/articles/cm240jyl09go
# Description: The Post Office returns a letter discovered 48 years after Tizi Hodson applied for her dream job.
#
# URL: https://www.bbc.com/news/northern_ireland/northern_ireland_politics
# Description: Get all the latest news, live updates and content about Northern Ireland Politics from across the BBC.
#
# URL: https://www.bbc.com/news/articles/c0r84p0dp1jo
# Description: A third body, not yet officially identified, is thought to be that of the attacker, the BBC understands.
#
# URL: https://www.bbc.com/news/articles/cpqzyvv2g4vo
# Description: A doctor tells the BBC of the moment she found out her clinic was next to an Israeli target building.
#
# URL: https://www.bbc.com/news/wales
# Description: Get all the latest news, live updates and content about Wales from across the BBC.
#
# URL: https://www.bbc.com/news/world/asia/india
# Description: Get all the latest news, live updates and content about India from across the BBC.
#
# URL: https://www.bbc.com/news/articles/c153pg278npo
# Description: Researchers are looking at making immunotherapy a much more effective treatment for cancer.
#
# URL: https://www.bbc.com/news/articles/c1e8g5leve0o
# Description: Baltimore is allowing people to buy homes for next to nothing to try to improve neighbourhoods.
#
# URL: https://www.bbc.com/news/videos/c89l8v3qd7go
# Description: More people are being prosecuted for dangerous driving thanks to a huge increase in footage submitted to police by the public.
#
# URL: https://www.bbc.com/news/wales/wales_politics
# Description: Get all the latest news, live updates and content about Welsh Politics from across the BBC.
#
# URL: https://www.bbc.com/usingthebbc/cookies/
# Description: Cookies help us remember you and show you more things we think you’ll like.
#
# URL: https://www.bbc.com/news/articles/c79nrgp97x9o
# Description: US scientists Victor Ambros and Gary Ruvkun helped explain how genes work inside the human body.
#
# URL: https://www.bbc.com/contact-bbc-com-help
# Description: Description not found
#
# URL: https://www.bbc.com/usingthebbc/privacy/
# Description: We take your privacy very seriously. And so should you.
#
# URL: https://www.bbc.com/news/topics/cj3ergr8209t
# Description: Follow all the latest news, live updates, videos, verified reports and expert analysis of US Election 2024 from BBC journalists in the US and around the world.
#
# URL: https://www.bbc.com/news/articles/c781vgy3918o
# Description: Twelve months on from the 7 October attacks which led to Israel's war in Gaza, our international editor says the region is on the edge of something even worse.
#
# URL: https://www.bbc.com/news/politics
# Description: Get all the latest news, live updates and content about Politics from across the BBC.
#
# URL: https://www.bbc.com/news/articles/c5y3qgqxpwno
# Description: A month from the election, misinformation is spreading as Republicans try to tie spending on the storm with immigration.
#
# URL: https://www.bbc.com/news/world/asia
# Description: Get all the latest news, live updates and content about Asia from across the BBC.
#
# URL: https://www.bbc.com/news/articles/c981pv02vryo
# Description: Officials in Kyiv say they hit an oil processing facility in the occupied peninsula overnight.
#
# URL: https://www.bbc.com/news/articles/cj4x71znwxdo
# Description: An in-depth look at the polls and what they can and can’t tell us about who will win the White House.
#
# URL: https://www.bbc.com/weather
# Description: Latest weather conditions and forecasts for the UK and the world. Includes up to 14-days of hourly forecast information, warnings, maps, and the latest editorial analysis and videos from the BBC Weather Centre.
#
# URL: https://www.bbc.com/news/articles/c206zn2gy37o
# Description: The top US court is back in session with cases that may affect American life - and its standing in the public.
#
# URL: https://www.bbc.com/news/videos/czrm4k1e7d0o
# Description: Multiple blasts shake the southern suburbs of Lebanon's capital amid Israeli air strikes.
#
# URL: https://www.bbc.com/news/articles/c5y923k2pwro
# Description: The indie musician says she is spending £40,000 of her own money to play the tour of her dreams.
#
# URL: https://www.bbc.com/news/articles/c30305l5jqpo
# Description: A year since scores of people were killed here, the collective is splintered - psychologically and physically.
#
# URL: https://www.bbc.com/news/topics/c2vdnvdg6xxt
# Description: Follow the latest news on the Israel Gaza war. Get live updates, maps, verified video reports and expert analysis from BBC journalists on the ground.
#
# URL: https://www.bbc.com/news/articles/ckg2987l8x7o
# Description: Gillian Millane says the climb to Everest base camp was "very emotional".
#
# URL: https://www.bbc.com/news/world-middle-east-20415675
# Description: A visual guide to how much has changed in the Gaza Strip since Israel began its military response to Hamas's attacks on 7 October.
#
# URL: https://www.bbc.com/news/live/cqxryqvz9j4t
# Description: The health ministry says the strike hit a municipal building in Bint Jbeil, as firefighters prepared to "embark on rescue missions".
#
# URL: https://www.bbc.com/news/videos/cx2ke88kx0ro
# Description: The BBC's Nick Beake reports from northern Israel, where Hezbollah continues to fire rockets into Israel.
#
# URL: https://www.bbc.com/news/articles/c206z9ggp9yo
# Description: Janice Combs says her son is "not perfect" but is not guilty of the sex charges filed against him.
#
# URL: https://www.bbc.com/news/articles/cz04n1kg1d4o
# Description: With one month to go, any unexpected event could help sway this close race for the White House.
#
# URL: https://www.bbc.com/news/articles/cx20dr33xjeo
# Description: The town is undergoing its own healing process ahead of the former president's visit.

# %%
# Main scraping function
def scrape_multiple_pages(n):
    base_url = 'https://www.bbc.com/news'
    bbc_headlines, bbc_author, bbc_url, bbc_description = [], [], [], []

    for page in range(1, n + 1):
        doc = get_doc(base_url)
        
        # Extract data from each page
        headlines = list(get_headlines_newsarticles(doc))  
        authors = list(fetch_author_name(doc))            
        urls = list(get_article_url(doc))                  
        descriptions = list(fetch_article_description(doc)) 
        
        # Ensure lists are of the same length by appending placeholder values if needed
        max_len = max(len(headlines), len(authors), len(urls), len(descriptions))
        
        # Adjust all lists to the same length
        headlines += ['Missing Headline'] * (max_len - len(headlines))
        authors += ['Unknown Author'] * (max_len - len(authors))
        urls += ['Unknown URL'] * (max_len - len(urls))
        descriptions += ['No Description'] * (max_len - len(descriptions))
        
        # Append data to the main lists
        bbc_headlines.extend(headlines)
        bbc_author.extend(authors)
        bbc_url.extend(urls)
        bbc_description.extend(descriptions)

    # Create a dictionary with the scraped data
    bbc_data = {
        'HEADLINES': bbc_headlines,
        'AUTHOR': bbc_author,
        'LINK': bbc_url,
        'DESCRIPTION': bbc_description
    }

    # Convert the dictionary to a DataFrame
    bbc_df = pd.DataFrame(bbc_data)

    # Save the DataFrame to a CSV file
    bbc_df.to_csv('bbc_news_data.csv', index=False)

    return bbc_df

# Example usage: Scrape 1 page of BBC news and save to CSV
scraped_data = scrape_multiple_pages(1)
print(scraped_data.head())
# Out:
#                                            HEADLINES  \
# 0  'Far too many civilians have suffered,' Biden ...
# 1  Bowen: Year of killing and broken assumptions ...
# 2  Hezbollah rockets hit northern Israeli city of...
# 3        My son's not a monster, says Diddy's mother
# 4    Japan's government admits editing cabinet photo
#
#                                               AUTHOR  \
# 0                                              Error
# 1  Error fetching article: No connection adapters...
# 2                                     Unknown Author
# 3                                     Unknown Author
# 4                                     Unknown Author
#
#                                              LINK DESCRIPTION
# 0             https://www.bbc.com/news/bbcindepth           E
# 1         https://www.bbc.com/news/war-in-ukraine           r
# 2           https://www.bbc.com/news/world/europe           r
# 3                     https://www.bbc.com/news/uk           o
# 4  https://www.bbc.com/news/articles/c8dj0833g99o           r
